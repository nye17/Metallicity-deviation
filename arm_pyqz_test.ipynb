# %%
# %matplotlib inline
import pyqz

import numpy as np

# %%
import sys
sys.path
# Out:
# ['',
#  '/home/yhwang/local/anaconda/envs/pyqz/lib/python27.zip',
#  '/home/yhwang/local/anaconda/envs/pyqz/lib/python2.7',
#  '/home/yhwang/local/anaconda/envs/pyqz/lib/python2.7/plat-linux2',
#  '/home/yhwang/local/anaconda/envs/pyqz/lib/python2.7/lib-tk',
#  '/home/yhwang/local/anaconda/envs/pyqz/lib/python2.7/lib-old',
#  '/home/yhwang/local/anaconda/envs/pyqz/lib/python2.7/lib-dynload',
#  '/home/yhwang/local/anaconda/envs/pyqz/lib/python2.7/site-packages',
#  '/home/yhwang/local/anaconda/envs/pyqz/lib/python2.7/site-packages/pyqz-0.8.4.0-py2.7.egg',
#  '/home/yhwang/local/anaconda/envs/pyqz/lib/python2.7/site-packages',
#  '/home/yhwang/local/anaconda/envs/pyqz/lib/python2.7/site-packages/IPython/extensions',
#  '/home/yhwang/.ipython']

# %%
import pyqz
print pyqz.__version__
# Out:
# 0.8.4

# %%
a_grid = pyqz.get_grid('[NII]/[SII]+;[OIII]/[SII]+', sampling=1)
print a_grid
# Out:
# [array([[  6.50000000e+00,   8.11000000e+00,   8.00000000e+00,
#          -4.07400000e-01,  -9.85300000e-01,  -4.07400000e-01,
#          -9.85300000e-01],
#        [  6.50000000e+00,   8.48500000e+00,   8.37500000e+00,
#          -2.49400000e-01,  -1.20430000e+00,  -2.49400000e-01,
#          -1.20430000e+00],
#        [  6.50000000e+00,   8.63500000e+00,   8.52500000e+00,
#          -1.98600000e-01,  -1.43220000e+00,  -1.98600000e-01,
#          -1.43220000e+00],
#        [  6.50000000e+00,   8.83500000e+00,   8.72500000e+00,
#          -1.12000000e-01,  -1.83900000e+00,  -1.12000000e-01,
#          -1.83900000e+00],
#        [  6.50000000e+00,   8.98500000e+00,   8.87500000e+00,
#          -6.00000000e-02,  -2.43430000e+00,  -6.00000000e-02,
#          -2.43430000e+00],
#        [  6.75000000e+00,   8.11000000e+00,   8.00000000e+00,
#          -2.95600000e-01,  -3.74300000e-01,  -2.95600000e-01,
#          -3.74300000e-01],
# ...

# %%
pyqz.pyqzm.pyqz_grid_dir='/usr/local/share/mappings/data'

# %%
pyqz.pyqzm.pyqz_grid_dir
# Out:
# '/home/yhwang/local/anaconda/envs/pyqz/lib/python2.7/site-packages/pyqz/ref_data'

# %%
pyqz.pyqzm.pyqz_dir
# Out:
# '/home/yhwang/local/anaconda/envs/pyqz/lib/python2.7/site-packages/pyqz'

# %%
a_grid = pyqz.get_grid('[NII]/[SII]+;[OIII]/[SII]+', sampling=1)

# %%
a_grid = pyqz.get_grid('[NII]/[SII]+;[OIII]/[SII]+', struct = 'pp', Pk = 5, kappa = 'inf')

# %%
import pyqz.pyqz_plots as pyqzp

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
# 关闭tex，恢复正常
from matplotlib import rc
rc("text", usetex=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
a = np.array(range(30))
plt.hist(a,bins=5,label="${test^{\odot}-1.4}$");
plt.legend(loc="best")
plt.show()

# %%
def dispFonts():
    #显示可用的中文字体，同时支持英文的
    from matplotlib.font_manager import FontManager
    import subprocess

    fm = FontManager()
    mat_fonts = set(f.name for f in fm.ttflist)

    output = subprocess.check_output(
        'fc-list :lang=US -f "%{family}\n"', shell=True)
    output = output.decode('utf-8')
    # print ‘*‘ * 10, ‘系统可用的中文字体‘, ‘*‘ * 10
    # print output
    zh_fonts = set(f.split(',', 1)[0] for f in output.split('\n'))
    available = mat_fonts & zh_fonts

    print '*' * 10 +  u'可用的中文字体'+'*' * 10
    for f in available:
        print(f)
dispFonts()
# Out:
# **********可用的中文字体**********

# %%
# Out:
# **********可用的中文字体**********

# %%
# %matplotlib inline
import pyqz

import numpy as np
import pyqz.pyqz_plots as pyqzp
pyqzp.plot_grid('[NII]/[OII]+;[OIII]/[OII]+', struct = 'pp', Pk = 5, kappa = 'inf',color_mode='gas[O]+12')#,figname='/root/lalala.png');

# %%
import pyqz

import numpy as np
import pyqz.pyqz_plots as pyqzp
pyqz.pyqzm.pyqz_cmap_0 = 'jet'
# pyqz.pyqzm.pyqz_cmap_0 = 'RdGnBu'
# pyqz.pyqzm.pyqz_cmap_1 = 'RdYlBu'



pyqzp.plot_grid('[NII]/[OII]+;[OIII]/[OII]+', struct = 'pp', Pk = 5, kappa = 'inf',color_mode='gas[O]+12',sampling=1)

# %%
pyqzp.plot_grid('[NII]/[OII]+;[OIII]/[OII]+', struct = 'pp', Pk = 5, kappa = 'inf',color_mode='gas[O]+12',sampling=1)

# %%
# 根据横纵坐标得到金属丰度的大小。
niioii = np.array([-0.65])
oiiisii = np.array([-0.1])
z = pyqz.interp_qz('Tot[O]+12',[niioii, oiiisii],'[NII]/[OII]+;[OIII]/[SII]+',
                   sampling=1,struct='pp')
print 'Tot[O]+12 = %.2f' % z

# The result can be visualized using pyqz_plots.plot_grid()
pyqzp.plot_grid('[NII]/[OII]+;[OIII]/[SII]+',sampling = 1, struct='pp', data = [niioii,oiiisii], interp_data=z)

# %%
pyqzp.pyqz.get_grid('[NII]/[OII]+;[OIII]/[OII]+', struct = 'pp', Pk = 5, kappa = 'inf')
# Out:
# [array([[ 6.5   ,  8.11  ,  8.    , -1.1183, -1.6963, -1.1183, -1.6963],
#         [ 6.5   ,  8.485 ,  8.375 , -0.8166, -1.7715, -0.8166, -1.7715],
#         [ 6.5   ,  8.635 ,  8.525 , -0.6317, -1.8652, -0.6317, -1.8652],
#         [ 6.5   ,  8.835 ,  8.725 , -0.2943, -2.0213, -0.2943, -2.0213],
#         [ 6.5   ,  8.985 ,  8.875 ,  0.091 , -2.2833,  0.091 , -2.2833],
#         [ 6.75  ,  8.11  ,  8.    , -1.1697, -1.2484, -1.1697, -1.2484],
#         [ 6.75  ,  8.485 ,  8.375 , -0.8537, -1.3284, -0.8537, -1.3284],
#         [ 6.75  ,  8.635 ,  8.525 , -0.6605, -1.4262, -0.6605, -1.4262],
#         [ 6.75  ,  8.835 ,  8.725 , -0.318 , -1.5916, -0.318 , -1.5916],
#         [ 6.75  ,  8.985 ,  8.875 ,  0.0715, -1.8686,  0.0715, -1.8686],
#         [ 7.    ,  8.11  ,  8.    , -1.2276, -0.8138, -1.2276, -0.8138],
#         [ 7.    ,  8.485 ,  8.375 , -0.8939, -0.8985, -0.8939, -0.8985],
#         [ 7.    ,  8.635 ,  8.525 , -0.691 , -0.9984, -0.691 , -0.9984],
# ...

# %%
pyqzp.pyqz.get_grid?

# %%
fn = pyqz.pyqz_tools.get_MVphotogrid_fn(Pk = 5.0, calibs = 'GCZO', kappa = np.inf, struct = 'pp', sampling = 1)
info = pyqz.pyqz_tools.get_MVphotogrid_metadata(fn)

print 'MAPPINGS id: %s' % info['MV_id']
print 'Model created: %s' % info['date']
print 'Model parameters: %s' % info['params'].split(': ')[1]
# Out:
# MAPPINGS id: MAPPINGS V HII Region Grid: QZ pp_GCZO_Pk50_kinf
# Model created: Thu Dec 10 14:16:36 CLST 2015
# Model parameters: pp,two,LPk=5.0,dep=Depln_Fe_1.50.txt,kap=inf,GCZFea05t2,SF=cont,a05,isp,#11,P6,Mv5.0.16,Svm802,FE15

# %%
pyqzp.plot_grid('[NII]/[OII]+;[OIII]/[OII]+', struct = 'pp', Pk = 5, kappa = 'inf', sampling=2)
# log[O iii]5007
# log([N ii]6584/[O ii]3726+3729)

# %%
pyqz.get_global_qz(np.array([[ 1.00e+00, 5.00e-02, 2.38e+00, 1.19e-01, 5.07e+00, 2.53e-01,
                               5.67e-01, 2.84e-02, 5.11e-01, 2.55e-02, 2.88e+00, 1.44e-01]]),
                   ['Hb','stdHb','[OIII]','std[OIII]','[OII]+','std[OII]+',
                    '[NII]','std[NII]','[SII]+','std[SII]+','Ha','stdHa'],
                   ['[NII]/[SII]+;[OIII]/Hb','[NII]/[OII]+;[OIII]/[SII]+'],
                   ids = ['NGC_1234'],
                   KDE_method = 'multiv',
                   KDE_qz_sampling = 201j,
                   struct = 'pp',
                   sampling = 1,
                   verbose = True)
# Out:
#
# --> Received 1 spectrum ...
# --> Dealing with them one at a time ... be patient now !
#     (no status update until I am done ...)
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/pyqz/pyqz.py:434: RuntimeWarning: invalid value encountered in greater
#   this_interp_data[this_interp_data>0]
#
# All done in 0:00:01.449299
# [array([[  7.38831887e+00,   8.48760006e+00,   7.37681443e+00,
#            8.48372388e+00,   7.38256665e+00,   5.75221877e-03,
#            8.48566197e+00,   1.93808636e-03,   7.40791471e+00,
#            5.55948429e-02,   8.49599900e+00,   5.59232823e-02,
#            7.38019910e+00,   2.89873940e-02,   8.48326527e+00,
#            2.75916351e-02,   7.38382781e+00,   3.32681756e-02,
#            8.48403878e+00,   3.06823659e-02,   0.00000000e+00,
#            0.00000000e+00]]),
#  ['[NII]/[SII]+;[OIII]/Hb|LogQ',
#   '[NII]/[SII]+;[OIII]/Hb|Tot[O]+12',
#   '[NII]/[OII]+;[OIII]/[SII]+|LogQ',
#   '[NII]/[OII]+;[OIII]/[SII]+|Tot[O]+12',
#   '<LogQ>',
# ...

# %%
pyqz.pyqz.interp_qz(qz, data, ratios, coeffs=[[1, 0], [0, 1]], Pk=5.0, kappa=inf, struct='pp', sampling=1, method='cubic')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-6a9e69f17cf5> in <module>()
# ----> 1 pyqz.pyqz.interp_qz(qz, data, ratios, coeffs=[[1, 0], [0, 1]], Pk=5.0, kappa=inf, struct='pp', sampling=1, method='cubic')
#
# NameError: name 'qz' is not defined

# %%
out = pyqz.get_global_qz(np.array([[ 1.00e+00, 5.00e-02, 2.38e+00, 1.19e-01, 5.07e+00, 2.53e-01,
                                     5.67e-01, 2.84e-02, 5.11e-01, 2.55e-02, 2.88e+00, 1.44e-01]]),
                   ['Hb','stdHb','[OIII]','std[OIII]','[OII]+','std[OII]+',
                    '[NII]','std[NII]','[SII]+','std[SII]+','Ha','stdHa'],
                   ['[NII]/[SII]+;[OIII]/Hb','[NII]/[OII]+;[OIII]/[SII]+'],
                   ids = ['NGC_1234'],
                   KDE_method = 'multiv',
                   KDE_qz_sampling = 201j,
                   KDE_pickle_loc = './examples/',
                   struct = 'pp',
                   sampling = 1,
                   verbose = True)

import glob
fn = glob.glob('./examples/*NGC_1234*.pkl')

# pyqz_plots.get_global_qz() takes the pickle filename as argument.
pyqzp.plot_global_qz(fn[0], show_plots=True, save_loc = './examples/', do_all_diags=True)
# Out:
#
# --> Received 1 spectrum ...
# --> Dealing with them one at a time ... be patient now !
#     (no status update until I am done ...)
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-16cb21d3cbeb> in <module>()
#      10                    struct = 'pp',
#      11                    sampling = 1,
# ---> 12                    verbose = True)
#      13
#      14 import glob
#
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/pyqz/pyqz.pyc in get_global_qz(data, data_cols, which_grids, ids, qzs, Pk, kappa, struct, sampling, error_pdf, srs, flag_level, KDE_method, KDE_qz_sampling, KDE_do_singles, KDE_pickle_loc, verbose, nproc)
#    1206                 print '    (no status update until I am done ...)'
#    1207
# -> 1208             results = map(get_global_qz_singlespec, jobs)
#    1209
#    1210         else:
#
# ...

# %%
# %matplotlib inline
import pyqz
import pyqz.pyqz_plots as pyqzp

# %%
fn = pyqz.pyqzt.get_MVphotogrid_fn(Pk=6.7, calibs='GCZO', kappa =10, struct='pp')
print fn.split('/')[-1]
# Out:
# MVgrid_QZ_pp_GCZO_Pk67_k10.csv

# %%
grid_fn = pyqz.pyqzt.get_MVphotogrid_fn(Pk=5.0,struct='sph', kappa='inf')
pyqz.pyqzt.resample_MVphotogrid(grid_fn, sampling=2)
# Out:
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/scipy/interpolate/_cubic.py:306: RuntimeWarning: invalid value encountered in double_scalars
#   m[-1] = 2. * m[-2] - m[-3]
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/numpy/lib/function_base.py:1768: RuntimeWarning: invalid value encountered in subtract
#   return a[slice1]-a[slice2]
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/scipy/interpolate/_cubic.py:317: RuntimeWarning: invalid value encountered in greater
#   ind = np.nonzero(f12 > 1e-9 * np.max(f12))
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/scipy/interpolate/_cubic.py:323: RuntimeWarning: invalid value encountered in subtract
#   c = (3. * m[2:-2] - 2. * t[:-1] - t[1:]) / dx
#
#   Success: MVgrid_QZ_sph_GCZO_Pk50_kinf.csv resampled by a factor 2x2 and saved as MVgrid_QZ_sph_GCZO_Pk50_kinf_samp_2.csv

# %%
pyqzp.plot_grid('[NII]/[SII]+;[NII]/Ha;[OIII]/Hb',
                     coeffs = [[1.0,0.264,0.0],[0.242,-0.910,0.342]],
                     struct='pp',
                     sampling=1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     248     if 'retina' in formats or 'png2x' in formats:
#     249         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ...

# %%
#import matplotlib
#mpl.use('Agg')
#%matplotlib inline
#import matplotlib

import matplotlib.pyplot as plt
import pyqz
import numpy as np
import pyqz.pyqz_plots as pyqzp
#a_grid = pyqz.get_grid('[NII]/[SII]+;[OIII]/[SII]+', sampling=1)

#%matplotlib inline
pyqzp.plot_grid('[NII]/[OII]+;[OIII]/[OII]+', struct = 'pp', Pk = 5, kappa = 'inf', sampling=2, show_plot=True)
# Out:
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
# ...

# %%
# %matplotlib inline
import matplotlib
matplotlib.pyplot.show()

# %%
import matplotlib

# %%
fn = pyqz.pyqzt.get_MVphotogrid_fn(Pk=5, calibs='GCZO', kappa ='inf', struct='pp')
#print fn.split('/')[-1]
print fn.split()[-0]
# Out:
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/pyqz/ref_data/MVgrid_QZ_pp_GCZO_Pk50_kinf.csv

# %%
#import matplotlib
#mpl.use('Agg')
#import matplotlib.pyplot as plt
import pyqz
import numpy as np
import pyqz.pyqz_plots as pyqzp
a_grid = pyqz.get_grid('[NII]/[SII]+;[OIII]/[SII]+', sampling=1)


pyqzp.plot_grid('[NII]/[OII]+;[OIII]/[OII]+', struct = 'pp', Pk = 5, kappa = 'inf', sampling=2, show_plot=True)
#pyqzp.plt.imshow(lala)
#pyqzp.plt.show()
# Out:
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /root/anaconda3/envs/pyqzz/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
# ...

# %%
import matplotlib.pyplot as plt
plt.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
pyqzp.plot_grid?

# %%
import matplotlib.pyplot as plt
plt.show()

# %%
matplotlib.figure.
pyqzp.
pyqzp.plt.imshow()
pyqzp.plt.show()
